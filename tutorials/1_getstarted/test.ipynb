-- %%
dofile 'getstarted.lua'
-- Out:
-- basic printing
-- 10
-- something
-- number
-- string
-- Console does not support images
-- Console does not support images
-- Console does not support images
